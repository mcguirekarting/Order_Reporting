# %%
import sys 
sys.path.append(r"C:\Users\mcgui\VS Code\Projects (DEV)\Order_Reporting")
from utils import oracle_db_utils as db
import oracledb
from importlib import reload
reload(db)


import os
def get_oracle_connection() -> oracledb.Connection:
    """
    Create an Oracle database connection using environment variables.
    """
    try:
        db_user = os.environ.get("ORACLE_USER", "System")
        db_password = os.environ.get("ORACLE_PASSWORD", "password123")
        db_host = os.environ.get("ORACLE_HOST", "localhost")
        db_port = int(os.environ.get("ORACLE_PORT", "1521"))
        db_service = os.environ.get("ORACLE_SERVICE", "XEPDB1")

        dsn = oracledb.makedsn(db_host, db_port, service_name=db_service)

        connection = oracledb.connect(
            user=db_user,
            password=db_password,
            dsn=dsn
        )
    except oracledb.DatabaseError as e:
        print(f"Database connection error: {e}")
        raise
    return connection

connection = get_oracle_connection()
cursor = connection.cursor()

cursor.execute("SELECT 1 FROM dual")
print(cursor.fetchall())


cursor.close()
connection.close()
# Out:
# Database connection error: DPY-6005: cannot connect to database (CONNECTION_ID=/NO9NkZe9I82EJZZut5OKQ==).
# [WinError 10061] No connection could be made because the target machine actively refused it
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File src/oracledb/impl/thin/connection.pyx:404, in oracledb.thin_impl.ThinConnImpl._connect_with_address()
#
# File src/oracledb/impl/thin/protocol.pyx:268, in oracledb.thin_impl.Protocol._connect_phase_one()
#
# File src/oracledb/impl/thin/protocol.pyx:402, in oracledb.thin_impl.Protocol._connect_tcp()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     850 if not all_errors:
# --> 851     raise exceptions[0]
#     852 raise ExceptionGroup("create_connection failed", exceptions)
#
# ...

# %%
import json
import logging
import os
import oracledb
from datetime import datetime
from typing import List, Dict, Any, Optional


logger = logging.getLogger("oracle_db_utils")

# Configure Oracle client if needed
def get_db_connection():
    """
    Get an Oracle database connection using credentials from environment variables
    
    Returns:
        oracledb.Connection: Database connection object
    """
    try:
        # Get connection details from environment variables
        db_user = os.environ.get("ORACLE_USER", "report_user")
        db_password = os.environ.get("ORACLE_PASSWORD", "report_password")
        db_host = os.environ.get("ORACLE_HOST", "localhost")
        db_port = int(os.environ.get("ORACLE_PORT", "1521"))
        db_service = os.environ.get("ORACLE_SERVICE", "XEPDB1")
        db_tablespace = os.environ.get("ORACLE_TABLESPACE", "users")
        
        # Create DSN
        dsn = oracledb.makedsn(db_host, db_port, service_name=db_service)
        
        # Create connection
        connection = oracledb.connect(user=db_user, password=db_password, dsn=dsn)
        
        
        logger.info(f"Successfully connected to Oracle database: {db_host}:{db_port}/{db_service}")
        return connection
        
    except oracledb.Error as error:
        logger.error(f"Error connecting to Oracle database: {error}")
        raise

# %%
        import sys
        print(sys.path)
# Out:
# ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\python311.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\Lib', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0', '', 'C:\\Users\\mcgui\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages', 'C:\\Users\\mcgui\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\win32', 'C:\\Users\\mcgui\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\win32\\lib', 'C:\\Users\\mcgui\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.1
# ...
